# %% [markdown]
# # SPATIAL INTELLIGENCE - PART 1

# %% [markdown]
# # 1. Import the needed classes
# # 2. Check the TopologicPy version
# # 3. Set your renderer

# %%
from topologicpy.Vertex import Vertex
from topologicpy.Edge import Edge
from topologicpy.Wire import Wire
from topologicpy.Face import Face
from topologicpy.Shell import Shell
from topologicpy.Cell import Cell
from topologicpy.CellComplex import CellComplex
from topologicpy.Cluster import Cluster
from topologicpy.Topology import Topology
from topologicpy.Dictionary import Dictionary
from topologicpy.Helper import Helper
from topologicpy.Grid import Grid
from topologicpy.Graph import Graph
from topologicpy.Color import Color

print("This tutorial requires topologicpy version 0.9.18 or newer.")
print(Helper.Version())

renderer = "vscode"
print(renderer)

# %% [markdown]
# ## 4. Import the OBJ file

# %%
objects = Topology.ByOBJPath(r"C:\IaaC\AIA\GraphML\hand_wassimtutorial.obj")
print("Objects is a list")
print(objects)
# Out:
# Objects is a list
# [<topologic_core.Cluster object at 0x0000021666445FF0>, <topologic_core.Cluster object at 0x00000216662C9230>, <topologic_core.Cluster object at 0x00000216664940B0>, <topologic_core.Cluster object at 0x000002166642DAB0>, <topologic_core.Cluster object at 0x00000216662CA3F0>, <topologic_core.Cluster object at 0x000002166645D8F0>, <topologic_core.Cluster object at 0x000002166645D930>, <topologic_core.Cluster object at 0x000002166640E3F0>, <topologic_core.Cluster object at 0x000002166640F670>, <topologic_core.Cluster object at 0x000002166640D2F0>, <topologic_core.Cluster object at 0x000002166645D870>, <topologic_core.Cluster object at 0x000002166642D930>, <topologic_core.Cluster object at 0x000002166640D3B0>, <topologic_core.Cluster object at 0x00000216662CB4F0>, <topologic_core.Cluster object at 0x000002166645C9B0>, <topologic_core.Cluster object at 0x000002166645C5B0>, <topologic_core.Cluster object at 0x0000021666494070>]

# %% [markdown]
# ## 5. Show OG the geometry

# %%
Topology.Show(objects,
              backgroundColor="white",
              opacityKey='FakeKey',
              faceOpacityKey='FakeKey',
              width=500,
              height=500,
              renderer=renderer)

# Topology.Show(objects,
#               faceColor=[210,210,250],
#               faceOpacity=1,
#               edgeColor="white",
#               edgeWidth=3,
#               showVertices=False,
#               backgroundColor="black",
#               width=800,
#               height=600,
#               renderer = renderer)

# %% [markdown]
# ## 5. Apply color to different cells via name in Rhino

# %%
cells = []
selectors = []
for object in objects:
    d = Topology.Dictionary(object)
    faces = Topology.Faces(object)
    if len(faces) > 1:
        c = Cell.ByFaces(faces)
        c = Topology.RemoveCollinearEdges(c)
        s = Topology.InternalVertex(c)
        name = Dictionary.ValueAtKey(d, "name")
        if "Joint_1" in name:
            color = "red"
        elif "Joint_2" in name:
            color = "green"
        elif "Joint_3" in name:
            color = "blue"
        else:
            color = "white"
        d = Dictionary.SetValuesAtKeys(d, ["color", "vertex_size"], [color, 20])
        s = Topology.SetDictionary(s, d)
        selectors.append(s)
        cells.append(c)
        print(Dictionary.Keys(d), Dictionary.Values(d))

print(len(cells))
# Out:
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['white', 'Palm_2', '', 'Palm_2', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['green', 'Joint_2_5', '', 'Joint_2_5', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['red', 'Joint_1_5', '', 'Joint_1_5', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['blue', 'Joint_3_4', '', 'Joint_3_4', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['green', 'Joint_2_4', '', 'Joint_2_4', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['red', 'Joint_1_4', '', 'Joint_1_4', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['blue', 'Joint_3_3', '', 'Joint_3_3', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['green', 'Joint_2_3', '', 'Joint_2_3', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['red', 'Joint_1_3', '', 'Joint_1_3', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['blue', 'Joint_3_2', '', 'Joint_3_2', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['green', 'Joint_2_2', '', 'Joint_2_2', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['red', 'Joint_1_2', '', 'Joint_1_2', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['blue', 'Joint_3_1', '', 'Joint_3_1', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['green', 'Joint_2_1', '', 'Joint_2_1', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['red', 'Joint_1_1', '', 'Joint_1_1', 1.0, 20]
# ['color', 'group', 'material', 'name', 'opacity', 'vertex_size'] ['white', 'Palm_1', '', 'Palm_1', 1.0, 20]
# 16

# %%
hand = CellComplex.ByCells(cells)
hand = Topology.TransferDictionariesBySelectors(hand, selectors, tranCells=True)
hand_cells = Topology.Cells(hand)
for hand_cell in hand_cells:
    d = Topology.Dictionary(hand_cell)
    print(Dictionary.Keys(d), Dictionary.Values(d))
# Out:
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[0.0, -70.0, 0.0, 190.0, 60.0, 60.0], 'white', 'Palm_2', '', 'Palm_2', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[-10.0, 30.0, 0.0, 190.0, 118.654533, 60.0], 'white', 'Palm_1', '', 'Palm_1', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[-90.0, -40.0, 0.0, 0.0, 90.0, 60.0], 'green', 'Joint_2_5', '', 'Joint_2_5', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[-20.0, 110.0, 0.0, 29.530748, 170.0, 60.0], 'blue', 'Joint_3_4', '', 'Joint_3_4', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[29.530748, 111.796852, 0.0, 75.918478, 170.0, 60.0], 'blue', 'Joint_3_3', '', 'Joint_3_3', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[75.918478, 113.905385, 0.0, 138.443299, 180.0, 60.0], 'blue', 'Joint_3_2', '', 'Joint_3_2', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[138.443299, 116.747423, 0.0, 180.399733, 180.0, 60.0], 'blue', 'Joint_3_1', '', 'Joint_3_1', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[-120.0, 60.0, 0.0, -70.0, 140.0, 60.0], 'red', 'Joint_1_5', '', 'Joint_1_5', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[-30.0, 160.0, 0.0, 20.0, 230.0, 60.0], 'green', 'Joint_2_4', '', 'Joint_2_4', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[30.0, 170.0, 0.0, 70.0, 230.0, 60.0], 'green', 'Joint_2_3', '', 'Joint_2_3', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[90.0, 170.0, 0.0, 130.0, 230.0, 60.0], 'green', 'Joint_2_2', '', 'Joint_2_2', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[150.0, 170.0, 0.0, 170.0, 220.0, 60.0], 'green', 'Joint_2_1', '', 'Joint_2_1', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[-30.0, 230.0, 0.0, 10.0, 290.0, 60.0], 'red', 'Joint_1_4', '', 'Joint_1_4', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[30.0, 230.0, 0.0, 70.0, 310.0, 60.0], 'red', 'Joint_1_3', '', 'Joint_1_3', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[90.0, 230.0, 0.0, 120.0, 300.0, 60.0], 'red', 'Joint_1_2', '', 'Joint_1_2', 1.0, 20]
# ['aabb', 'color', 'group', 'material', 'name', 'opacity', 'vertex_size'] [[150.0, 220.0, 0.0, 170.0, 250.0, 60.0], 'red', 'Joint_1_1', '', 'Joint_1_1', 1.0, 20]

# %%
Topology.Show(hand_cells, 
              faceColorKey="color",
              vertexSizeKey="vertex_size",
              opacityKey='FakeKey',
              faceOpacityKey='FakeKey',
              edgeColor="white",
              edgeWidth=3,
              showVertices=True,
              backgroundColor="black",
              width=800,
              height=600,
              renderer = renderer)
