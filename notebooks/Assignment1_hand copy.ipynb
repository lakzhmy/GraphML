# %% [markdown]
# # SPATIAL INTELLIGENCE - PART 1

# %% [markdown]
# # 1. Import the needed classes
# # 2. Check the TopologicPy version
# # 3. Set your renderer

# %%
from topologicpy.Vertex import Vertex
from topologicpy.Edge import Edge
from topologicpy.Wire import Wire
from topologicpy.Face import Face
from topologicpy.Shell import Shell
from topologicpy.Cell import Cell
from topologicpy.CellComplex import CellComplex
from topologicpy.Cluster import Cluster
from topologicpy.Topology import Topology
from topologicpy.Dictionary import Dictionary
from topologicpy.Helper import Helper
from topologicpy.Grid import Grid
from topologicpy.Graph import Graph
from topologicpy.Color import Color

print("This tutorial requires topologicpy version 0.9.18 or newer.")
print(Helper.Version())

renderer = "vscode"
print(renderer)

# %% [markdown]
# ## 4. Import the OBJ file

# %%
objects = Topology.ByOBJPath(r"C:\IaaC\AIA\GraphML\hand_boxes6.obj")
print("Objects is a list")
print(objects)
# Out:
# Objects is a list
# [<topologic_core.Cluster object at 0x00000216662DE070>, <topologic_core.Cluster object at 0x00000216662DC230>, <topologic_core.Cluster object at 0x00000216662A76F0>, <topologic_core.Cluster object at 0x00000216662DC630>, <topologic_core.Cluster object at 0x00000216662DC4F0>, <topologic_core.Cluster object at 0x00000216662DC2B0>, <topologic_core.Cluster object at 0x00000216662DCE30>, <topologic_core.Cluster object at 0x00000216662DCDF0>, <topologic_core.Cluster object at 0x00000216662DDBB0>, <topologic_core.Cluster object at 0x00000216662DC5B0>, <topologic_core.Cluster object at 0x00000216662DC7B0>, <topologic_core.Cluster object at 0x00000216662DF9F0>, <topologic_core.Cluster object at 0x00000216662DC770>, <topologic_core.Cluster object at 0x00000216662DFFB0>, <topologic_core.Cluster object at 0x00000216662DC830>, <topologic_core.Cluster object at 0x00000216662DC3F0>, <topologic_core.Cluster object at 0x00000216662A6EB0>]

# %% [markdown]
# ## 6. Show the geometry

# %%
Topology.Show(objects,
              backgroundColor="white",
              opacityKey='FakeKey',
              faceOpacityKey='FakeKey',
              width=500,
              height=500,
              renderer=renderer)

# Topology.Show(objects,
#               faceColor=[210,210,250],
#               faceOpacity=1,
#               edgeColor="white",
#               edgeWidth=3,
#               showVertices=False,
#               backgroundColor="black",
#               width=800,
#               height=600,
#               renderer = renderer)
